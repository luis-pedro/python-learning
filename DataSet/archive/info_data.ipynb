# %% [markdown]
# Importando as bibliotecas necessárias
#
# numpy - biblioteca matemática
# pandas - biblioteca de manipulação do dataframe
# matplotlib - biblioteca de gráficos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
